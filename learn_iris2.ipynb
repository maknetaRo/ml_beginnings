# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
import urllib

# %%
iris = datasets.load_iris()

# %%
url = "http://aima.cs.berkeley.edu/data/iris.csv"
set1 = urllib.request.Request(url)
iris_p = urllib.request.urlopen(set1)
iris = pd.read_csv(iris_p, sep=',', decimal='.', header=None, 
                          names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width','target'])

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# target          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
fig = iris[iris.target=='setosa'].plot(kind='scatter',x='sepal_length',y='sepal_width',color='orange', label='Setosa')
iris[iris.target=='versicolor'].plot(kind='scatter',x='sepal_length',y='sepal_width',color='blue', label='versicolor',ax=fig)
iris[iris.target=='virginica'].plot(kind='scatter',x='sepal_length',y='sepal_width',color='green', label='virginica', ax=fig)
fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()
# had to use word target instead of Species or class 
# the graph shows relationship between the sepal length and width

# %%
fig = iris[iris.target=='setosa'].plot.scatter(x='petal_length', y='petal_width', color='orange', label='Setosa')
iris[iris.target=='versicolor'].plot.scatter(x='petal_length', y='petal_width', color='blue', label='Versicolor', ax=fig)
iris[iris.target=='virginica'].plot.scatter(x='petal_length', y='petal_width', color='green', label='Virginica', ax=fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title(" Petal Length Vs Width ")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# how the length and width are distributed 
iris.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
# How the length and width vary according to the species 
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='target', y='petal_length', data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='target', y='petal_width', data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='target', y='sepal_length', data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='target', y='sepal_width', data=iris)

# %%
# The violinplot shows density of the length and width in the species. 
# The thinner part denotes that there is less density whereas the fatter part conveys higher density
